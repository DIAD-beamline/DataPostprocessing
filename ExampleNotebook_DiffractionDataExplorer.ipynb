# %%
from diffractionDataExplorer_class import DiffractionDataExplorer

# %% [markdown]
# # Diffraction Viewer with explicit paths
# Update the full paths:
# 1. Diffraction postprocessing nxs data
# 2. Imaging nxs data (either radiography raw, tomography raw, tomography reconstruction)
# 3. Output directory and file root path
# 4. Optional index of the projection (this is used on for radiography datasets)

# %%
DIFF_View_1 = DiffractionDataExplorer(
    "/dls/staging/dls/k11/data/2024/mg34950-1/processed/k11-38031-diffraction-DiffInt_HarmCakeAzzTxt.nxs",
    "/dls/staging/dls/k11/data/2024/mg34950-1/processed/Savu_k11-38030_full_fd_rr_vo_AST_tiff/k11-38030_processed.nxs",
    "/dls/staging/dls/k11/data/2024/mg34950-1/processing/image", 0)
DIFF_View_1.InputOutput()
DIFF_View_1.DataExplorer()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Diffraction Viewer with no predefined paths
# The first cell will request to specify the path for:
# 1. Diffraction postprocessing nxs data
# 2. Imaging nxs data (either radiography raw, tomography raw, tomography reconstruction)
# 3. Output directory and file root path
# 4. Optional index of the projection (this is used on for radiography datasets)

# %%
DIFF_View_2 = DiffractionDataExplorer()
DIFF_View_2.InputOutput()
# Out:
# ---------------------------------------------------------------------------
# InvalidPathError                          Traceback (most recent call last)
# /tmp/ipykernel_2922943/1402266659.py in <cell line: 2>()
#       1 DIFF_View_2 = DiffractionDataExplorer()
# ----> 2 DIFF_View_2.InputOutput()
#
# ~/Documents/Development/DataPostprocessing/diffractionDataExplorer_class.py in InputOutput(self)
#     306
#     307         if self.Dif_Path == None:
# --> 308             dfile_chooser = FileChooser(self.VisitPath)
#     309             dfile_chooser.title = 'Diffraction Data Reduction:'
#     310             dfile_chooser.register_callback(self.load_diffraction)
#
# ~/.local/lib/python3.10/site-packages/ipyfilechooser/filechooser.py in __init__(self, path, filename, title, select_desc, change_desc, show_hidden, select_default, dir_icon, dir_icon_append, show_only_dirs, filter_pattern, sandbox_path, layout, **kwargs)
#      40             raise InvalidFileNameError(filename)
# ...

# %% [markdown]
# Once the paths have been selected run the viewer

# %%
DIFF_View_2.DataExplorer()
