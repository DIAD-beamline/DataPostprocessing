# %%
from diffractionDataExplorer_class import DiffractionDataExplorer

# %%
DIFF_View = DiffractionDataExplorer()
DIFF_View.InputOutput()
# Out:
# FileChooser(path='/dls/k11/data', filename='', title='Diffraction Data Reduction:', show_hidden=False, select_…
# FileChooser(path='/dls/k11/data', filename='', title='Tomography Reconstruction:', show_hidden=False, select_d…
# FileChooser(path='/dls/k11/data', filename='', title='Output File Path Root (without extension):', show_hidden…

# %%
### DIFF_View.DataExplorer() ##

# %%
DIFF_View_1 = DiffractionDataExplorer(
    "/dls/staging/dls/k11/data/2024/mg34950-1/processed/k11-38031-diffraction-DiffInt_HarmCakeAzzTxt.nxs",
    "/dls/staging/dls/k11/data/2024/mg34950-1/processed/Savu_k11-38030_full_fd_rr_vo_AST_tiff/k11-38030_processed.nxs",
    "/dls/staging/dls/k11/data/2024/mg34950-1/processing/image")
DIFF_View_1.InputOutput()
DIFF_View_1.DataExplorer()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
