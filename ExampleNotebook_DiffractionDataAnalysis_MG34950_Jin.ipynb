# %%
from diffractionDataAnalysis_class import DiffractionDataAnalysis

# %%
DIFF_View_1 = DiffractionDataAnalysis(
    "/dls/staging/dls/k11/data/2024/mg34950-1/processed/k11-38034-diffraction-DiffInt_HarmCakeAzzTxt.nxs",
    "/dls/staging/dls/k11/data/2024/mg34950-1/nexus/37947",
    "/dls/staging/dls/k11/data/2024/mg34950-1/processed/Savu_k11-38033_full_fd_rr_vo_AST_tiff/k11-38033_processed.nxs",
    "/dls/staging/dls/k11/data/2024/mg34950-1/processing/image", 0)

# %%
DIFF_View_1.InputOutput()

# %%
DIFF_View_1.ImageCorrelatedCrystallography_Azimuthal(1.73,1.94,1,0.10)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DIFF_View_1.ImageCorrelatedCrystallography_Azimuthal_Explore(1.73,1.94,1,0.10)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DIFF_View_1.ImageCorrelatedCrystallography_Cake(1.73,1.94,1,0.10)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
